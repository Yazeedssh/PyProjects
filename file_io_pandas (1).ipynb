# %% [markdown]
# # File I/O
# Reading and writing files.

# %% [markdown]
# ## Working with paths

# %%
from pathlib import Path
# !wget --no-check-certificate 'https://ia600508.us.archive.org/34/items/data_20231009/data.zip' -O data.zip
# Out:
# --2023-10-22 05:51:07--  https://ia600508.us.archive.org/34/items/data_20231009/data.zip
# Resolving ia600508.us.archive.org (ia600508.us.archive.org)... 207.241.227.188
# Connecting to ia600508.us.archive.org (ia600508.us.archive.org)|207.241.227.188|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261631 (255K) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 255.50K  1.28MB/s    in 0.2s
#
# 2023-10-22 05:51:07 (1.28 MB/s) - ‘data.zip’ saved [261631/261631]

# %%
# !unzip data
# !rm -r __MACOSX/
# !rm data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#   inflating: __MACOSX/._data
#   inflating: data/london_weather.csv
#   inflating: __MACOSX/data/._london_weather.csv
#   inflating: data/supermarket_sales - Sheet1.csv
#   inflating: __MACOSX/data/._supermarket_sales - Sheet1.csv

# %%
#get the current path
current_file = Path("10_file_io.ipynb").resolve()

#get the parent directory
current_dir = current_file.parent

# %% [markdown]
# ### Excercise
# Try to navigate to the data folder.

# %%
# The path to data directory MUST be stored to data_dir
data_dir =current_dir/'data'

# %% [markdown]
# ## Path methods
#
# *   `path.exists()`   : chceck if the path exists
# *   `path.is_file()`  : check if path belongs to a file
# *   `path.is_dir()`   : check if the path belongs to a directory
#
# All these methods will return a boolean value.

# %%
print(f"exists: {data_dir.exists()}")
# try the other methods yourslef.
# Out:
# exists: True

# %% [markdown]
# ### Navigate to `london_weather.csv`
# create `data_path` and store the full path of `london_weather.csv`

# %%
data_path = '/content/data/london_weather.csv'

# %% [markdown]
# ### Reading files

# %%
data = {}
i = 0
with open(data_path) as example:
  for line in example:
    data[i] = line
    i=i+1

# %%
print(data)
# Out:
# {0: 'date,cloud_cover,sunshine,global_radiation,max_temp,mean_temp,min_temp,precipitation,pressure,snow_depth\n', 1: '19790101,2.0,7.0,52.0,2.3,-4.1,-7.5,0.4,101900.0,9.0\n', 2: '19790102,6.0,1.7,27.0,1.6,-2.6,-7.5,0.0,102530.0,8.0\n', 3: '19790103,5.0,0.0,13.0,1.3,-2.8,-7.2,0.0,102050.0,4.0\n', 4: '19790104,8.0,0.0,13.0,-0.3,-2.6,-6.5,0.0,100840.0,2.0\n', 5: '19790105,6.0,2.0,29.0,5.6,-0.8,-1.4,0.0,102250.0,1.0\n', 6: '19790106,5.0,3.8,39.0,8.3,-0.5,-6.6,0.7,102780.0,1.0\n', 7: '19790107,8.0,0.0,13.0,8.5,1.5,-5.3,5.2,102520.0,0.0\n', 8: '19790108,8.0,0.1,15.0,5.8,6.9,5.3,0.8,101870.0,0.0\n', 9: '19790109,4.0,5.8,50.0,5.2,3.7,1.6,7.2,101170.0,0.0\n', 10: '19790110,7.0,1.9,30.0,4.9,3.3,1.4,2.1,98700.0,0.0\n', 11: '19790111,1.0,6.8,55.0,2.9,2.6,0.3,2.3,98960.0,0.0\n', 12: '19790112,3.0,6.4,54.0,2.0,0.4,-2.0,0.0,100650.0,1.0\n', 13: '19790113,1.0,7.0,57.0,4.3,-2.6,-7.1,0.0,102350.0,1.0\n', 14: '19790114,7.0,0.0,14.0,6.7,-0.6,-5.6,0.8,102700.0,1.0\n', 15: '19790115,,0.0,15.0,5.9,3.8,1.0,0.1,102990.0,0.0\n', 16: '19790116,8.0,0.0,15.0,2.6,5.0,4.1,3.9,103100.0,0.0\n', 17: '19790117,8.0,0.0,15.0,1.9,2.1,1.6,2.5,102220.0,0.0\n', 18: '19790118,8.0,0.0,15.0,3.0,0.8,-0.2,0.2,101860.0,0.0\n', 19: '19790119,8.0,0.0,16.0,7.2,0.8,-1.4,5.2,100910.0,0.0\n', 20: '19790120,7.0,0.0,16.0,3.5,3.1,-1.0,0.0,100920.0,0.0\n', 21: '19790121,,0.0,16.0,1.5,0.0,-3.5,0.1,102170.0,0.0\n', 22: '19790122,8.0,0.0,16.0,0.3,-0.2,-1.8,6.2,101680.0,0.0\n', 23: '19790123,7.0,0.0,17.0,2.9,-1.0,-2.3,1.0,100970.0,6.0\n', 24: '19790124,3.0,4.8,54.0,5.6,-1.4,-5.6,1.4,101010.0,6.0\n', 25: '19790125,8.0,0.0,17.0,2.8,0.6,-4.5,5.3,99660.0,1.0\n', 26: '19790126,5.0,2.6,42.0,1.6,0.8,-1.1,0.1,99280.0,1.0\n', 27: '19790127,4.0,2.1,39.0,4.5,-1.8,-5.2,0.0,99770.0,0.0\n', 28: '19790128,7.0,3.1,47.0,4.8,0.0,-4.4,7.5,99470.0,0.0\n', 29: '19790129,4.0,1.0,31.0,4.0,1.9,-1.0,4.4,98920.0,0.0\n', 30: '19790130,5.0,0.8,30.0,7.3,0.7,-2.6,0.1,100070.0,0.0\n', 31: '19790131,5.0,1.6,38.0,9.1,2.1,-3.1,2.4,101390.0,0.0\n', 32: '19790201,8.0,0.0,19.0,4.0,5.2,1.2,10.1,99490.0,0.0\n', 33: '19790202,5.0,1.4,37.0,5.9,2.8,1.5,0.0,99890.0,0.0\n', 34: '19790203,1.0,8.7,85.0,4.5,0.9,-4.1,0.0,100770.0,0.0\n', 35: '19790204,8.0,0.1,23.0,6.0,1.6,-1.2,0.0,100060.0,0.0\n', 36: '19790205,6.0,0.8,33.0,4.0,3.7,1.4,0.0,100250.0,0.0\n', 37: '19790206,4.0,6.8,78.0,6.8,1.2,-1.6,9.0,101020.0,0.0\n', 38: '19790207,,0.0,21.0,3.7,3.3,-0.2,0.4,99450.0,0.0\n', 39: '19790208,6.0,1.9,45.0,4.0,2.0,0.3,0.0,100740.0,0.0\n', 40: '19790209,8.0,0.0,22.0,3.5,2.4,0.8,0.0,100310.0,0.0\n', 41: '19790210,8.0,0.0,23.0,2.9,2.8,2.1,0.0,99730.0,0.0\n', 42: '19790211,8.0,0.0,23.0,5.4,2.4,1.9,4.4,99170.0,0.0\n', 43: '19790212,8.0,0.1,27.0,8.1,2.8,0.3,6.7,98430.0,1.0\n', 44: '19790213,8.0,0.0,24.0,0.2,4.2,0.3,9.1,98130.0,0.0\n', 45: '19790214,6.0,2.4,54.0,-0.8,-0.2,-0.7,0.0,99380.0,1.0\n', 46: '19790215,7.0,0.0,25.0,0.6,-2.2,-3.7,0.1,100830.0,0.0\n', 47: '19790216,8.0,0.0,25.0,-0.8,-1.2,-3.1,0.0,102270.0,1.0\n', 48: '19790217,8.0,0.0,26.0,0.7,-1.2,-1.5,0.0,102180.0,0.0\n', 49: '19790218,8.0,0.0,26.0,1.9,-0.6,-1.8,0.0,101970.0,0.0\n', 50: '19790219,8.0,0.0,27.0,2.8,0.5,-0.9,0.1,102530.0,0.0\n', 51: '19790220,,0.0,27.0,3.6,1.6,0.3,0.0,103010.0,0.0\n', 52: '19790221,8.0,0.0,28.0,7.4,2.1,0.6,0.6,102640.0,0.0\n', 53: '19790222,5.0,2.6,63.0,8.7,4.3,1.2,1.8,102790.0,0.0\n', 54: '19790223,4.0,7.4,104.0,5.5,4.4,0.2,0.0,103430.0,0.0\n', 55: '19790224,4.0,1.9,58.0,6.9,2.9,0.3,0.0,104130.0,0.0\n', 56: '19790225,3.0,8.1,112.0,6.7,1.8,-3.4,0.0,104270.0,0.0\n', 57: '19790226,,4.2,82.0,8.9,1.6,-3.4,0.0,103590.0,0.0\n', 58: '19790227,6.0,4.4,85.0,6.1,3.7,-1.5,0.8,102090.0,0.0\n', 59: '19790228,6.0,2.1,64.0,9.7,4.4,2.7,0.9,100040.0,0.0\n', 60: '19790301,4.0,6.4,115.0,11.9,3.5,-2.7,0.2,101100.0,0.0\n', 61: '19790302,8.0,0.0,35.0,12.6,6.8,1.6,0.0,101640.0,0.0\n', 62: '19790303,8.0,0.1,40.0,10.5,11.0,9.4,5.3,101850.0,0.0\n', 63: '19790304,4.0,8.7,140.0,11.0,7.4,4.3,0.0,102410.0,0.0\n', 64: '19790305,4.0,6.4,121.0,9.0,5.4,-0.1,0.0,102730.0,0.0\n', 65: '19790306,6 ...

# %% [markdown]
# ## Writing files

# %%
new_file_path = data_dir / "new_file.txt"

with open(new_file_path, "w") as my_file:
    my_file.write("This is my first file that I wrote with Python.")

# %% [markdown]
# Now go and check that there is a new_file.txt in the data directory. After that you can delete the file by:

# %%
if new_file_path.exists():  # make sure it's there
  new_file_path.unlink()

# %% [markdown]
# ## Importing Pandas package
#
#
# *   Why we need packages in python?
#
# > A typical Python program is made up of several source files. Each source file is a module, grouping code and data for reuse. Modules are normally independent of each other, so that other programs can reuse the specific modules they need. Sometimes, to manage complexity, developers group together related modules into a package—a hierarchical, tree-like structure of related modules and subpackages.
#
# *   What is Pandas ?
#
# > pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %%
import pandas as pd

# %% [markdown]
# ## Reading data files

# %%
weather = pd.read_csv(data_path)

# %% [markdown]
# ### Using Pandas methods to manipulate data
#
#  Dataframe head and tail:
#
# *  `Dataframe.tail()`
# *  `Dataframe.head()`

# %%
weather.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
#Tray tail() yourself
weather.tail()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 15336  20201227          1.0       0.9              32.0       7.5        7.5
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
#        min_temp  precipitation  pressure  snow_depth
# 15336       7.6            2.0   98000.0         NaN
# 15337      -1.3            0.2   97370.0         NaN
# 15338       1.1            0.0   98830.0         NaN
# 15339      -0.1            0.0  100200.0         NaN
# 15340      -3.1            0.0  100500.0         NaN

# %% [markdown]
# ### `Dataframe.info()`
# Pandas dataframe.info() function is used to get a concise summary of the dataframe. It comes really handy when doing exploratory analysis of the data. To get a quick overview of the dataset we use the dataframe.info() function.

# %%
# show the summary of weather dataframe.
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  int64
#  1   cloud_cover       15322 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15322 non-null  float64
#  4   max_temp          15335 non-null  float64
#  5   mean_temp         15305 non-null  float64
#  6   min_temp          15339 non-null  float64
#  7   precipitation     15335 non-null  float64
#  8   pressure          15337 non-null  float64
#  9   snow_depth        13900 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.2 MB

# %% [markdown]
# ### `Dataframe.shape()`
# Shape shows the number of dimensions as well as the size in each dimension.

# %%
# show the shape of weather
weather.shape
# Out:
# (15341, 10)

# %% [markdown]
# ### `Dataframe.describe()`
# It does a quick statistical summary for every numerical column

# %%
# show quick statistical summary of weather
weather.describe()
# Out:
#                date   cloud_cover      sunshine  global_radiation  \
# count  1.534100e+04  15322.000000  15341.000000      15322.000000
# mean   1.999567e+07      5.268242      4.350238        118.756951
# std    1.212176e+05      2.070072      4.028339         88.898272
# min    1.979010e+07      0.000000      0.000000          8.000000
# 25%    1.989070e+07      4.000000      0.500000         41.000000
# 50%    2.000010e+07      6.000000      3.500000         95.000000
# 75%    2.010070e+07      7.000000      7.200000        186.000000
# max    2.020123e+07      9.000000     16.000000        402.000000
#
#            max_temp     mean_temp      min_temp  precipitation       pressure  \
# count  15335.000000  15305.000000  15339.000000   15335.000000   15337.000000
# mean      15.388777     11.475511      7.559867       1.668634  101536.605594
# std        6.554754      5.729709      5.326756       3.738540    1049.722604
# min       -6.200000     -7.600000    -11.800000       0.000000   95960.000000
# 25%       10.500000      7.000000      3.500000       0.000000  100920.000000
# 50%       15.000000     11.400000      7.800000       0.000000  101620.000000
# 75%       20.300000     16.000000     11.800000       1.600000  102240.000000
# max       37.900000     29.000000     22.300000      61.800000  104820.000000
#
#          snow_depth
# count  13900.000000
# mean       0.037986
# std        0.545633
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       22.000000

# %% [markdown]
# ### `nsmallest()` and `nlargest()`
# It shows the largest or smallest n values of a specific column in a dataframe.

# %%
weather.nsmallest(5,'min_temp')
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 1077   19811213          7.0       0.0              12.0       6.6       -3.6
# 1109   19820114          0.0       4.6              47.0       5.1       -4.2
# 2597   19860210          0.0       7.4              86.0       1.1       -4.4
# 11676  20101220          7.0       0.4              17.0       1.8       -4.1
# 2934   19870113          5.0       0.4              20.0      -1.4       -6.2
#
#        min_temp  precipitation  pressure  snow_depth
# 1077      -11.8           15.7   99610.0        20.0
# 1109      -10.1            0.0  102620.0        11.0
# 2597       -9.6            0.0  103150.0         3.0
# 11676      -9.4            0.0  100120.0         5.0
# 2934       -9.1            3.0  101380.0         1.0

# %% [markdown]
# ### excercise
#
#
# > Show the highest five days of snow depth in london.

# %%
weather.nlargest(5,'snow_depth')
# Out:
#           date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 1076  19811212          1.0       5.8              46.0       4.5       -4.4
# 1077  19811213          7.0       0.0              12.0       6.6       -3.6
# 1105  19820110          5.0       2.8              35.0       1.7       -3.6
# 1104  19820109          8.0       0.0              14.0      -0.8       -2.6
# 1106  19820111          4.0       7.0              56.0       2.4       -1.8
#
#       min_temp  precipitation  pressure  snow_depth
# 1076      -8.4            0.0  100670.0        22.0
# 1077     -11.8           15.7   99610.0        20.0
# 1105      -6.3            0.0  101110.0        18.0
# 1104      -3.6            1.9  101450.0        16.0
# 1106      -5.3            0.0  100750.0        15.0

# %% [markdown]
# ### `Dataframe.query()`
# We sometimes need to filter a dataframe based on a condition or apply a mask to get certain values. One easy way to filter a dataframe is query function.

# %%
weather.query('-3<min_temp<0')
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 4      19790105          6.0       2.0              29.0       5.6       -0.8
# 11     19790112          3.0       6.4              54.0       2.0        0.4
# 17     19790118          8.0       0.0              15.0       3.0        0.8
# 18     19790119          8.0       0.0              16.0       7.2        0.8
# 19     19790120          7.0       0.0              16.0       3.5        3.1
# ...         ...          ...       ...               ...       ...        ...
# 15306  20201127          7.0       0.8              34.0       6.5        2.9
# 15316  20201207          8.0       1.0              24.0       2.2        0.9
# 15335  20201226          NaN       2.1              38.0      10.0        4.9
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
#
#        min_temp  precipitation  pressure  snow_depth
# 4          -1.4            0.0  102250.0         1.0
# 11         -2.0            0.0  100650.0         1.0
# 17         -0.2            0.2  101860.0         0.0
# 18         -1.4            5.2  100910.0         0.0
# 19         -1.0            0.0  100920.0         0.0
# ...         ...            ...       ...         ...
# 15306      -0.6            0.2  101970.0         NaN
# 15316      -0.3            3.0   99940.0         NaN
# 15335      -0.1           12.0  101960.0         NaN
# 15337      -1.3            0.2   97370.0         NaN
# 15339      -0.1            0.0  100200.0         NaN
#
# [946 rows x 10 columns]

# %% [markdown]
# ### Excercise
#
# > Show dates where minimum temperature was less than -11 and snow depth was more than 10

# %%
weather.query('min_temp<-11 and snow_depth>10')
# Out:
#           date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 1077  19811213          7.0       0.0              12.0       6.6       -3.6
#
#       min_temp  precipitation  pressure  snow_depth
# 1077     -11.8           15.7   99610.0        20.0
